-- %% [markdown]
-- # [Voditeli]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Voditeli]    Script Date: 06.12.2021 14:06:39 ******/
CREATE DATABASE [Voditeli]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Voditeli', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Voditeli.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Voditeli_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Voditeli_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Voditeli] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Voditeli].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Voditeli] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Voditeli] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Voditeli] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Voditeli] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Voditeli] SET ARITHABORT OFF 
GO
ALTER DATABASE [Voditeli] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Voditeli] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Voditeli] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Voditeli] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Voditeli] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Voditeli] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Voditeli] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Voditeli] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Voditeli] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Voditeli] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Voditeli] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Voditeli] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Voditeli] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Voditeli] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Voditeli] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Voditeli] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Voditeli] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Voditeli] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Voditeli] SET  MULTI_USER 
GO
ALTER DATABASE [Voditeli] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Voditeli] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Voditeli] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Voditeli] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Voditeli] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Voditeli] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Voditeli] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Drivers]

-- %%
USE [Voditeli]
GO

-- %%
/****** Object:  Table [dbo].[Drivers]    Script Date: 06.12.2021 14:06:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Drivers](
	[ID] [int] NOT NULL,
	[Фамилия] [nvarchar](50) NULL,
	[Имя] [nvarchar](50) NULL,
	[Отчество] [nvarchar](50) NULL,
	[Паспорт (серия и номер)] [nvarchar](50) NULL,
	[Адрес регистрации] [nvarchar](50) NULL,
	[Адрес проживания] [nvarchar](50) NULL,
	[Место работы] [nvarchar](50) NOT NULL,
	[Должность] [nvarchar](50) NOT NULL,
	[Мобильный телефон] [nvarchar](50) NULL,
	[Email] [nvarchar](50) NULL,
	[Фотография] [nvarchar](50) NULL,
	[Замечания] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Drivers] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [Voditeli]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Voditeli] SET  READ_WRITE 
GO
